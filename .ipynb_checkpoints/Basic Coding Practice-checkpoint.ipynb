# %%
import sklearn

# %%
sklearn
# Out:
# <module 'sklearn' from 'C:\\Anaconda3\\lib\\site-packages\\sklearn\\__init__.py'>

# %%
pwd
# Out:
# 'C:\\Users\\ckp43_000\\Untitled Folder'

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-73edc048c06b> in <module>
# ----> 1 from sklearn.model_selection import train_test_split
#
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\__init__.py in <module>
#      17 from ._split import check_cv
#      18
# ---> 19 from ._validation import cross_val_score
#      20 from ._validation import cross_val_predict
#      21 from ._validation import cross_validate
#
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in <module>
#      25 from ..utils.metaestimators import _safe_split
#      26 from ..utils._joblib import Parallel, delayed
# ---> 27 from ..metrics.scorer import check_scoring, _check_multimetric_scoring
#      28 from ..exceptions import FitFailedWarning
#      29 from ._split import check_cv
#
# C:\Anaconda3\lib\site-packages\sklearn\metrics\__init__.py in <module>
# ...
